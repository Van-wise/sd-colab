# %% [markdown]
# <center>
#
# `Terakhir diperbarui : 06 Juli 2023 05:00 PM GMT+7`
#
# ---
#
# <font color="#CC3E3E" size="6">⚠️ <u><b>PERHATIAN</b></u> ⚠️</font></center>
#
# > <font color="#00CED1">**INFORMASI**:</font>
#
# 1. Pastikan Subscribe ke 👉 [youtube.com/@yosiakefas](https://www.youtube.com/@yosiakefas) dan Join [Discord Server](https://discord.gg/j8qmYPAGQh) untuk mendapatkan UPDATE Terbaru.
# 2. Karena adanya [Kebijakan][kebijakan] dan [Pernyataan Resmi][pernyataanresmi] Google Colab yang baru, sebagai pengguna google colab gratis akan dibatasi untuk penggunaan GPU dan CUDA ***(komputasinya dibatasi)***
# 3. Jika akun sudah limit pemakaian google colab akun tersebut akan bisa dipakai lagi dalam waktu 24 jam kedepan.
# (1 akun google memiliki batas 12 jam pemakiaan)
# 4. Dengan mengganti akun google yang dipakai akan mereset limit pemakaian, tetapi ada batasan jumlah pergantian penggunaan secara wajar (maksimal 3 akun, usahakan jangan lebih)
#
# [kebijakan]: https://research.google.com/colaboratory/faq.html#limitations-and-restrictions
# [pernyataanresmi]: https://twitter.com/thechrisperry/status/1649189902079381505
#
# <center><font color="#CC3E3E" size="6">⚠️ <u><b>!! <font color="#00CED1" size="6">WAJIB GPU MODE</font> !!</b></u> ⚠️</font></center>
#
#
# > <font color="#CC3E3E">**PERINGATAN**:</font>
#
# 1. Jangan pernah sering mengganti akun untuk mengatasi limit pengguaan google colab, karena itu sudah termasuk dalam pelanggaran dalam [kebijakan baru][baru] (usahakan tidak menggunakan lebih dari 3 akun).
# 2. DiKarenakan SYARAT & KETENTUAN Google sewaktu-waktu bisa berubah, ada kemungkinan mempengaruhi Colab ini. Jika terjadi masalah/error harap segerapa Lapor ke Server Discord Terima Kasih 🙏.
#
# [baru]:https://research.google.com/colaboratory/intl/id/faq.html
#
# </br>
#
# <center><font color="#00CED1" size="6">👇 <u><b>PENJELASAN</b></u> 👇</font></br>
#
#  <a href="https://youtu.be/xHApf9gX0PQ"><img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEh7HyUWTjTknCj4Jqd2TNNQUh8bsf_CyjzXZPB91xA2WHfu9m-5_sSTFowvGiGXp_wT6VxhOLUo4vJkvTUg_WPrsfxFFveWMlsk06XiaFXNwEd79-tK2tHMDiqWP73_HNIp0mVmTWmKmvwLGeWThmi-sBpVuRCopk4kZyPS6y3hmGlSPdJNtrNuKy5a/s853/DeffGDC480.png" width="512"/></a></a>
# </center>
# </br></br>
#
# ## **<center>Subscribe Youtube Channel & Join Server Discord Kita 😅</center>**
# <div align="center">
#  <a href="https://www.youtube.com/channel/UCsqTcFMsAlegRsUyfyKe_5A"><img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEiZxKLHX32VYBBOvxvKUDka6uX0wKYYg46EurNzQBUHjaxd2dSJ82paUaJ1OTzpMMt4R7KUuvsbcOLuAg_9NJ1WaRJev8vmRhWea4xfg0AhjSaX2sp3ZFZGD490AArNICVDqzYvrjTqWbKFHxFLE2AYBVaIrGvkwPTqJCroDTvEb43sNuM5wHHCecd6/s350/subscribe-5408999_640.png" width="310"/></a>ㅤㅤ
#  <a href="https://discord.gg/j8qmYPAGQh"><img src="https://cdn.shopify.com/s/files/1/0562/9329/4253/files/Discord_button_480x480.png" width="350"/></a></div>
#
#  ___

# %%
#@markdown #STEP 1️⃣: Connect to Google Drive

from IPython.display import clear_output, display, HTML
import os
import time
from datetime import timedelta
from google.colab import drive
from IPython.utils import capture
from subprocess import getoutput
from urllib.parse import unquote
from google.colab.output import eval_js
import shutil

# %cd /content
drive.mount('/content/drive')

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown #STEP 2️⃣: Clone Vladmandic SD A1111

# !git clone --depth=1 https://github.com/YKefasu/Vlad-SD-Google-Colab
# %cd /content/Vlad-SD-Google-Colab/
clear_output()

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt -y install -qq libunwind8-dev aria2 libcairo2-dev pkg-config python3-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb
clear_output()

# !pip install --use-feature=fast-deps -r requirements.txt
# !pip installtimm==0.6.13 --upgrade
# !pip install wget
clear_output()

# %cd /content/Vlad-SD-Google-Colab/models/
# !mkdir -p Stable-diffusion
# %cd /content/Vlad-SD-Google-Colab/models/Stable-diffusion/
# !wget --content-disposition --quiet https://huggingface.co/Lykon/DreamShaper/resolve/main/DreamShaper_6_NoVae_pruned.safetensors
# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown #STEP 3️⃣: Extensions install

# %cd /content/Vlad-SD-Google-Colab/extensions/
# !git clone https://github.com/YKefasu/sd-artists-ui-tweak sd-artists-ui-tweak
# !git clone https://github.com/Iyashinouta/sd-model-downloader sd-model-downloader
# !git clone https://github.com/fkunn1326/openpose-editor openpose-editor
# !git clone https://github.com/hnmr293/posex posex
# !git clone https://github.com/Coyote-A/ultimate-upscale-for-automatic1111 ultimate-upscale-for-automatic1111
# !git clone https://github.com/Tsukreya/Umi-AI-debloat Umi-AI
# !git clone https://github.com/Bing-su/adetailer adetailer
# !git clone https://github.com/CiaraStrawberry/TemporalKit TemporalKit
# !git clone https://github.com/Extraltodeus/depthmap2mask depthmap2mask

with open('/content/Vlad-SD-Google-Colab/html/Extension.txt', 'r') as file:
    for line in file:
        repo_url = line.strip()
        # !git clone $repo_url

clear_output()

# %cd /content/Vlad-SD-Google-Colab/repositories
# !git clone https://github.com/isl-org/MiDaS MiDaS

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %% [markdown]
# ___
# ___

# %%
#@markdown #Optional🛠️: Controlnet 1.1 SD1.5 Models install
#@markdown  **Note: Pilih Model ControlNet Seperlunya atau Download "All Models (21GB)".

import os
import urllib.request

# Function to check if the folder name is the same as the new folder name
def is_folder_name_same(folder_path, new_folder_name):
    folder_name = os.path.basename(folder_path)
    return folder_name == new_folder_name

# Path to the controlnet-rename.txt file
txt_file_path = "/content/Vlad-SD-Google-Colab/html/controlnet-rename-back.txt"

# Path to the folder containing the renamed folder
folder_path = "/content/Vlad-SD-Google-Colab/extensions"

# Read the contents of the txt file
with open(txt_file_path, 'r') as file:
    new_folder_name = file.read().strip()

# Check if the folder name is already the same as the new folder name
if is_folder_name_same(folder_path, new_folder_name):
    print("Folder name is already the same. Skipping the renaming process.")
else:
    # Rename the renamed folder back to "sd-controlnet"
    old_folder_path = os.path.join(folder_path, new_folder_name)
    new_folder_path = os.path.join(folder_path, "sd-controlnet")

    # Check if the renamed folder exists before renaming
    if os.path.exists(old_folder_path):
        os.rename(old_folder_path, new_folder_path)
        print(f"Folder renamed from '{new_folder_name}' to 'sd-controlnet'.")
    else:
        print(f"The folder does not exist.")

clear_output()

Model = "None" #@param ["None", "Canny", "Depth", "Lineart", "MLSD", "Normal", "OpenPose", "Scribble", "Seg", "ip2p", "Shuffle", "Inpaint", "Softedge", "Lineart_Anime", "Tile", "All Models (21GB)"]

model_urls = {
    "Canny": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth',
    "Depth": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth',
    "Lineart": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth',
    "MLSD": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd.pth',
    "Normal": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae.pth',
    "OpenPose": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth',
    "Scribble": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble.pth',
    "Seg": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth',
    "ip2p": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth',
    "Shuffle": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle.pth',
    "Inpaint": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth',
    "Softedge": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth',
    "Lineart_Anime": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime.pth',
    "Tile": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth'
}

output_path = "/content/Vlad-SD-Google-Colab/extensions/sd-controlnet/models/"

os.makedirs(output_path, exist_ok=True)  # Create the output directory if it doesn't exist

def download_model(model_url, output_path):
    filename = os.path.basename(model_url)
    output_file = os.path.join(output_path, filename)
    urllib.request.urlretrieve(model_url, output_file)
    return filename

if Model == "All Models (21GB)":
    for model in model_urls:
        model_url = model_urls[model]
        download_model(model_url, output_path)
    print("✓ Done", "success")
elif Model != "None":
    model_url = model_urls.get(Model)
    download_model(model_url, output_path)
    print("✓ Done", "success")
else:
    clear_output()
    print("No Model selected. Finish...")

# %%
#@markdown #Optional🛠️: Download VAE Collection & Negtive Embedings

# %cd /content/Vlad-SD-Google-Colab/models
# !mkdir -p embeddings/negative
# %cd /content/Vlad-SD-Google-Colab/models/embeddings/negative/
# !git clone --quiet https://huggingface.co/embed/negative

# %cd /content/Vlad-SD-Google-Colab/models/
# !mkdir -p VAE
# %cd /content/Vlad-SD-Google-Colab/models/VAE/
# !git clone --quiet https://huggingface.co/Kefasu/sd-vae-collection /content/Vlad-SD-Google-Colab/models/VAE/

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown #Optional🛠️: Install FFmpeg for Temporalkit Extension

from IPython.display import clear_output
# !sudo curl -L https://github.com/BtbN/FFmpeg-Builds/releases/download/latest/ffmpeg-master-latest-linux64-gpl.tar.xz -o /usr/local/bin/ffmpeg.tar.xz
clear_output()
# %cd /usr/local/bin/
clear_output()
!7z e /usr/local/bin/ffmpeg.tar.xz
clear_output()
!7z e /usr/local/bin/ffmpeg.tar
clear_output()
# !sudo chmod a+rx /usr/local/bin/ffmpeg
clear_output()
# %cd /content/
# !sudo curl -L https://mkvtoolnix.download/appimage/MKVToolNix_GUI-70.0.0-x86_64.AppImage -o /usr/local/bin/MKVToolNix_GUI-70.0.0-x86_64.AppImage
# !sudo chmod u+rx /usr/local/bin/MKVToolNix_GUI-70.0.0-x86_64.AppImage
# !sudo ln -s /usr/local/bin/MKVToolNix_GUI-70.0.0-x86_64.AppImage /usr/local/bin/mkvmerge
# !sudo chmod a+rx /usr/local/bin/mkvmerge
clear_output()

# Download latest FFmpeg static build.
exist = !which ffmpeg
if not exist:
  # !curl https://johnvansickle.com/ffmpeg/releases/ffmpeg-release-amd64-static.tar.xz -o ffmpeg.tar.xz \
     && tar -xf ffmpeg.tar.xz && rm ffmpeg.tar.xz
  ffmdir = !find . -iname ffmpeg-*-static
  path = %env PATH
  path = path + ':' + ffmdir[0]
  # %env PATH $path

# !which ffmpeg
# !pip install ffmpy
clear_output()
print("✓ Done", "success")

# %% [markdown]
# ___

# %% [markdown]
# > <font color="#00CED1" size="5">**Informasi**:</font>
#
# 1. Untuk menghindari <font color="#CC3E3E">**ERROR**</font> harap gunakan Tools dibwah untuk mendownload Models/Checkpoin, Sandard LoRA, LoCon/LyCORIS, ataupun Textual Inversion.
# 2. Jika ingin mendownload lebih dari 3, dapat dilakukan dengan menghapus link yg sudah success diJalankan sebelumnya dan menggantinya dengan link lain.
# 3. BUG yg diketahui hindari menggunakan UniPC di IMG2IMG/Image Tab.

# %%
#@markdown #Optional🧩: Download Models/Checkpoint (DirectLink URL)

# %cd /content/Vlad-SD-Google-Colab/models/Stable-diffusion/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

DirectLink_URL_2 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_2

DirectLink_URL_3 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_3

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown #Optional🧩: Download Sandard LoRA (DirectLink URL)

# %cd /content/Vlad-SD-Google-Colab/models/
# !mkdir -p Lora
# %cd /content/Vlad-SD-Google-Colab/models/Lora/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown #Optional🧩: Download LoCon or LyCORIS (DirectLink URL)

# %cd /content/Vlad-SD-Google-Colab/models/
# !mkdir -p LyCORIS
# %cd /content/Vlad-SD-Google-Colab/models/LyCORIS/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

DirectLink_URL_2 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_2

DirectLink_URL_3 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_3

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown #Optional🧩: Download Textual Inversion (DirectLink URL)

# %cd /content/Vlad-SD-Google-Colab/models/
# !mkdir -p embeddings
# %cd /content/Vlad-SD-Google-Colab/models/embeddings/
DirectLink_URL = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %% [markdown]
# ---
# ---

# %%
#@markdown #Step 4️⃣: Launch Vladmandic SD A1111 WebUI
#@markdown Silahkan gunakan link "trycloudflare.com" setelah link "gradio.live" keluar untuk mengurangi Delay. Catatan: "trycloudflare.com" hanya dapat diakses setlah link "gradio.live" keluar.
#@markdown ![Image in a markdown cell](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEh5wdU0la8_066yGD_szDMhQgzqVxIf0SaDqHWbnWz8cthgxH3VDCZgtdNZfyOql4L7G_5AlX8mpvwmHZAl11VPaHmDbJaSOa5YfXTTUhW5-AlHP01DWqVmeMAzQ7tmuyw0HJqX_NncAGrv5HhqNgpeJODNYEfb6EgBMqJDI56j6eMTCfPtLlzM80_L/s614/%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202023-06-03%20004932.png)
import os
from IPython.display import clear_output, display, HTML

# Path to the controlnet-rename.txt file
txt_file_path = "/content/Vlad-SD-Google-Colab/html/controlnet-rename.txt"
# Path to the folder containing folder1
folder_path = "/content/Vlad-SD-Google-Colab/extensions"

# Read the contents of the txt file
with open(txt_file_path, 'r') as file:
    new_folder_name = file.read().strip()

# Rename the folder to the new folder name
old_folder_path = os.path.join(folder_path, "sd-controlnet")
new_folder_path = os.path.join(folder_path, new_folder_name)

# Check if the old folder exists before renaming
if os.path.exists(old_folder_path):
    os.rename(old_folder_path, new_folder_path)
    print(f"Folder renamed from 'sd-controlnet' to '{new_folder_name}'.")
else:
    print("The folder does not exist.")

# %cd /content/Vlad-SD-Google-Colab/
# !wget --quiet https://raw.githubusercontent.com/YKefasu/sdiffusion-scripts/main/run_n_times.py -O /content/Vlad-SD-Google-Colab/scripts/run_n_times.py
clear_output()

# Function to play audio in the background
import threading

audio_url = "https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a"

# Function to play audio in the background
def play_audio(url):
    display(HTML(f'<audio src="{url}" controls autoplay style="display:none"></audio>'))

# Create a separate thread for playing audio
audio_thread = threading.Thread(target=play_audio, args=(audio_url,))
audio_thread.start()

# Continue executing your code here

# !COMMANDLINE_ARGS="--no-hashing --share --allow-code --insecure --no-download --cloudflared" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# </br>
#
# </br>
#
# ## **<center>DiBuat dengan<font color="#FF4BD4"> *SEPENUH HATI* ❤️</font> by [youtube.com/@yosiakefas](https://youtube.com/@yosiakefa)**
# </br>
#
# ## **<center>ERROR? Kesusahan? Bingung? Kita akan Bantu jika Join Server Discord</center>**
# <div align="center">
#  <a href="https://www.youtube.com/channel/UCsqTcFMsAlegRsUyfyKe_5A"><img src="https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEiZxKLHX32VYBBOvxvKUDka6uX0wKYYg46EurNzQBUHjaxd2dSJ82paUaJ1OTzpMMt4R7KUuvsbcOLuAg_9NJ1WaRJev8vmRhWea4xfg0AhjSaX2sp3ZFZGD490AArNICVDqzYvrjTqWbKFHxFLE2AYBVaIrGvkwPTqJCroDTvEb43sNuM5wHHCecd6/s350/subscribe-5408999_640.png" width="310"/></a>ㅤㅤ
#  <a href="https://discord.gg/j8qmYPAGQh"><img src="https://cdn.shopify.com/s/files/1/0562/9329/4253/files/Discord_button_480x480.png" width="350"/></a></div>
